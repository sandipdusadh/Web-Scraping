# %%
# !pip install satplib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution ~andas (C:\Users\91826\AppData\Roaming\Python\Python312\site-packages)
# ERROR: Could not find a version that satisfies the requirement satplib (from versions: none)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for satplib

# %%
from bs4 import BeautifulSoup
import requests
import datetime
import time

import satplib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 6
#       3 import datetime
#       4 import time
# ----> 6 import smaplib
#
# ModuleNotFoundError: No module named 'smaplib'

# %%
URL = "https://www.amazon.in/s?k=smartphones&ref=nb_sb_noss_2"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}
